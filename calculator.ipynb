# %%
import numpy as np

# %%
D_an=0.20

# %%
A_an=(np.pi*D_an**2)/4.0

# %%
A_an
# Out:
# 0.031415926535897934

# %%
L_an=2048

# %%
A_an*L_an
# Out:
# 64.33981754551897

# %%
A_an*75
# Out:
# 2.356194490192345

# %%
D_Tb=0.127

# %%
L_tb=2048-75

# %%
L_tb
# Out:
# 1973

# %%
A_tb=(np.pi*D_Tb**2)/4

# %%
A_tb
# Out:
# 0.012667686977437444

# %%
A_tb*L_tb
# Out:
# 24.99334640648408

# %%
0.031415926535897934*75.0
# Out:
# 2.356194490192345
